# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np

# %%
filename = "MEDIDA10_100KHZ_50000_BOBINA_ARRANQUE"
ext = ".med"

# %%
df = pd.read_csv (filename+ext, sep='\t', decimal=',', names=['t','ch1','ch2','ch3','ch4'])

# %%
df = df.drop(['ch2','ch3','ch4'],axis=1)

# %%
df.set_index('t').plot()
# Out:
# <AxesSubplot:xlabel='t'>
